# %% [markdown]
# # Imports

# %%
import maurikit_learn as ml
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Data

# %%
#Embaralha dados
dados = np.loadtxt("data1.txt", delimiter=",")

#Embaralhando as amostras
np.random.shuffle(dados)

#Separa dados
X = dados[:,0:2]
y = dados[:,2]

#Normalização
X = (X - X.min()) / (X.max() - X.min())

#Separação de conjunto de treino e conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Rede MLP

# %% [markdown]
# ## Camada Oculta de Tamanho 2

# %%
mlp = ml.redeMLP(input_layer_size=2, hidden_layer_size=2)

# %%
mlp.fit(X, y, epochs=50, learning_rate=0.01)

# %%
y_pred = mlp.predict(X)

# %% [markdown]
# #### Acurácia

# %%
ml.acuracia(y, y_pred)
# Out:
# 0.9

# %% [markdown]
# #### Matriz de Confusão

# %%
ml.plot_confusion_matrix(mlp, X, y)
# Out:
# Matriz de Confusão
# [[35  5]
#  [ 5 55]]

# %% [markdown]
# #### Gráfico de Dispersão

# %%
ml.plot_boundaries(mlp, X, y)

# %% [markdown]
# #### 5-Fold

# %%
fold_mlp = ml.redeMLP(hidden_layer_size=2)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.93 0.89 0.86 0.89 0.91]

# %% [markdown]
# ## Camada Oculta de Tamanho 3

# %%
mlp = ml.redeMLP(input_layer_size=2, hidden_layer_size=3)

# %%
mlp.fit(X, y, epochs=50, learning_rate=0.01)

# %%
y_pred = mlp.predict(X)

# %% [markdown]
# #### Acurácia

# %%
ml.acuracia(y, y_pred)
# Out:
# 0.9

# %% [markdown]
# #### Matriz de Confusão

# %%
ml.plot_confusion_matrix(mlp, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  1]
#  [ 2 19]]

# %% [markdown]
# #### Gráfico de Dispersão

# %%
ml.plot_boundaries(mlp, X, y)

# %% [markdown]
# #### 5-Fold

# %%
fold_mlp = ml.redeMLP(hidden_layer_size=3)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.93 0.89 0.86 0.89 0.91]

# %% [markdown]
# ## Camada Oculta de Tamanho 4

# %%
mlp = ml.redeMLP(input_layer_size=2, hidden_layer_size=4)

# %%
mlp.fit(X, y, epochs=50, learning_rate=0.01)

# %%
y_pred = mlp.predict(X)

# %% [markdown]
# #### Acurácia

# %%
ml.acuracia(y, y_pred)
# Out:
# 0.9

# %% [markdown]
# #### Matriz de Confusão

# %%
ml.plot_confusion_matrix(mlp, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  1]
#  [ 2 19]]

# %%
ml.plot_boundaries(mlp, X, y)

# %% [markdown]
# #### 5-Fold

# %%
fold_mlp = ml.redeMLP(hidden_layer_size=4)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.61 0.56 0.68 0.91 0.91]

# %% [markdown]
# # KNN

# %% [markdown]
# ## K = 1

# %%
knn = ml.knn(k=1)

# %%
knn.fit(X, y)

# %%
y_pred = knn.predict(X)

# %%
ml.acuracia(y, y_pred)
# Out:
# 1.0

# %%
ml.plot_confusion_matrix(knn, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 9  0]
#  [ 0 21]]

# %%
ml.plot_boundaries(mlp, X, y)

# %%
fold_mlp = ml.knn(k=1)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.81 0.86 0.91 0.84 0.84]

# %% [markdown]
# ## K = 2

# %%
knn = ml.knn(k=2)
knn.fit(X, y)

# %%
y_pred = knn.predict(X)

# %%
ml.acuracia(y, y_pred)
# Out:
# 0.94

# %%
ml.plot_confusion_matrix(knn, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 9  0]
#  [ 2 19]]

# %%
ml.plot_boundaries(mlp, X, y)

# %%
fold_mlp = ml.knn(k=2)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.84 0.88 0.86 0.81 0.86]

# %% [markdown]
# ## K = 3

# %%
knn = ml.knn(k=3)
knn.fit(X, y)

# %%
y_pred = knn.predict(X)

# %%
ml.acuracia(y, y_pred)
# Out:
# 0.95

# %%
ml.plot_confusion_matrix(knn, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  1]
#  [ 1 20]]

# %%
ml.plot_boundaries(mlp, X, y)

# %%
fold_mlp = ml.knn(k=3)
ml.k_fold(X, y, 5, fold_mlp)
# Out:
# Erros:  [0.84 0.86 0.88 0.84 0.88]
